# %% [markdown]
# **<font color="red" size=5>Note :</font>**
# <font size=5>
# Click the <button class="btn btn-success"><i class="fa fa-lg fa-id-card-o"></i> Web</button> button
# </font>

# %%
output = ! rm -rf Setup_Notebook && git clone https://github.com/pupster90/Setup_Notebook.git
# %run Setup_Notebook/default.ipynb
output = ! rm -rf io_Start_Screen && git clone https://github.com/pupster90/io_Start_Screen.git
# %run io_Start_Screen/embed.ipynb
